# %% [markdown]
# <a href="https://colab.research.google.com/github/Sridevi-coder62/seaborn-probability-distributions/blob/main/Data_Distributions_Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# I. Random Permutation

# %% [markdown]
# Randomly shuffle elements of following array:

# %%
import numpy as np
from numpy import random

x= np.array([1,2,3,4,5])
random.shuffle(x)
print(x)
# Out:
# [3 4 5 2 1]

# %% [markdown]
# Generate a random permutation of elements of following array:

# %%
arr=np.array([2,5,6,8,9,10])
print("Permutation: ", random.permutation(arr))
# Out:
# Permutation:  [ 2  8  5  9  6 10]

# %% [markdown]
# II. Seaborn Module

# %% [markdown]
# Plotting a Displot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot([0,1,2,3,4,5])
plt.show()

# %% [markdown]
# Plotting a Displot Without the Histogram

# %%
sns.displot([0,1,2,3,4,5], kind='kde')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# III. Normal (Gaussian) Distribution

# %% [markdown]
# Generate a random normal distribution of size 2x3:

# %%
X=random.normal(size=(2,3))
print(X)
# Out:
# [[ 1.66176922 -1.26052987 -1.79062738]
#  [-0.17481563  1.08291413  1.43659289]]

# %% [markdown]
# Generate a random normal distribution of size 2x3 with mean at 1 and standard deviation of 2:

# %%
X= random.normal(loc=1,scale=2,size=(2,3))
print(X)
# Out:
# [[-0.45579414 -0.09503256 -0.43783102]
#  [ 1.34985505  1.00694399  1.36899351]]

# %% [markdown]
# Visualization of Normal Distribution

# %%
sns.displot(random.normal(size=1000),kind='kde')
plt.show()

# %% [markdown]
# IV. Binomial Distribution

# %% [markdown]
# Given 10 trials for coin toss generate 10 data points:

# %%
x = random.binomial(n=10,p=0.5,size=10)
print(x)
# Out:
# [4 3 5 8 4 2 8 5 7 3]

# %% [markdown]
# Visualization of Binomial Distribution

# %%
sns.displot(random.binomial(n=10,p=0.5,size=1000))
plt.show()

# %%
data={
    'normal': random.normal(loc=50,scale=5,size=1000),
    'binomial':random.binomial(n=100,p=0.5,size=1000)
}

sns.displot(data,kind='kde')
plt.show()

# %% [markdown]
# V. Poisson Distribution

# %% [markdown]
# Generate a random 1x10 distribution for occurrence 2:

# %%
A= random.poisson(lam=2,size=10)
print(A)
# Out:
# [1 1 1 2 2 2 1 3 3 2]

# %% [markdown]
# Visualization of Poisson Distribution

# %%
sns.displot(random.poisson(lam=2,size=1000))
plt.show()

# %%
data2={
    'normal': random.normal(loc=50,scale=7,size=1000),
    'poisson': random.poisson(lam=50,size=1000)
}
sns.displot(data2,kind='kde')
plt.show()

# %% [markdown]
# Difference Between Binomial and Poisson Distribution

# %%
data3={
    'binomial': random.binomial(n=1000,p=0.01,size=1000),
    'poisson': random.poisson(lam=10,size=1000)
}
sns.displot(data3,kind='kde')
plt.show(

)

# %% [markdown]
# VI.Uniform Distribution

# %% [markdown]
# Create a 2x3 uniform distribution sample:

# %%
x=random.uniform(size=(2,3))
print(x)
# Out:
# [[0.62592599 0.27110633 0.44680778]
#  [0.22914869 0.18666661 0.57918483]]

# %% [markdown]
# Visualization of Uniform Distribution

# %%
sns.displot(random.uniform(size=1000),kind='kde')
plt.show()

# %% [markdown]
# VII. Logistic Distribution

# %% [markdown]
# Draw 2x3 samples from a logistic distribution with mean at 1 and stddev 2.0:

# %%
x=random.logistic(loc=1,scale=2.0,size=(2,3))
print(x)
# Out:
# [[ 1.92791205  7.32189712  0.83193322]
#  [-0.660842    0.24548675  2.43586095]]

# %% [markdown]
# Visualization of Logistic Distribution

# %%
sns.displot(random.logistic(size=1000),kind='kde')
plt.show()

# %% [markdown]
# Difference Between Logistic and Normal Distribution

# %%
data4={
    'logistic': random.logistic(size=1000),
    'normal': random.normal(scale=2,size=1000)
}
sns.displot(data4,kind='kde')
plt.show()

# %% [markdown]
# VIII.Multinomial Distribution

# %% [markdown]
# Draw out a sample for dice roll:

# %%
x=random.multinomial(n=6,pvals=[1/6,1/6,1/6,1/6,1/6,1/6])
print(x)
# Out:
# [2 0 1 0 2 1]

# %% [markdown]
# IX.Exponential Distribution

# %% [markdown]
# Draw out a sample for exponential distribution with 2.0 scale with 2x3 size:

# %%
x=random.exponential(scale=2,size=(2,3))
print(x)
# Out:
# [[6.21043149 0.43376741 1.03113678]
#  [1.82290165 3.00082651 1.79558627]]

# %% [markdown]
# Visualization of Exponential Distribution

# %%
sns.displot(random.exponential(size=1000),kind='kde')
plt.show()

# %% [markdown]
# X. Chi Square Distribution

# %% [markdown]
# Draw out a sample for chi squared distribution with degree of freedom 2 with size 2x3:

# %%
x=random.chisquare(df=2,size=(2,3))
print(x)
# Out:
# [[2.5028484  0.35822525 0.6502734 ]
#  [0.21790831 2.285281   2.23233488]]

# %% [markdown]
# Visualization of Chi Square Distribution

# %%
sns.displot(random.chisquare(df=1,size=1000),kind='kde')
plt.show()
